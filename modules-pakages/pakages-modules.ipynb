# %%
# modules and pakages are used to make code more modular and resuse the code again and again
# eg :-  import math where math is a pakage
import math
math.sqrt(44)
# Out:
# 6.6332495807108

# %%
from math import pi,sin
print(pi)
# Out:
# 3.141592653589793

# %%
import numpy as np  # here np is the alias for numpy

# %%
# to import all the modules present inside of a pakage
from math import *
sqrt(100)
# Out:
# 10.0

# %%
from pakage.addition import addtion

addtion(10,20)
# Out:
# 30

# %%
from pakage.subpakage.multiply import multiply
multiply(10,10)
# Out:
# 100
