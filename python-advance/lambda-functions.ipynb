# %%
# lambda functions are small function defined with the help of lambda keyword
# these fucntions can have many number of argumnets but only single expression
# syntax lamba arguments: expression

addition = lambda a,b :a+b
type(addition)

print(addition(2,3))
# Out:
# 5

# %%
even = lambda num: num%2==0

print(even(200))
# Out:
# True
