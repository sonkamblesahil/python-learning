# %%
# exception handling in python enables the corrective handling of programs and proper execution of code 

# exceptions are the some of events that disrupt the normal execution of the program 
# some of the common exceptions are listed below
# divisionbbyzero
# ioexception
# filenotfounderror
# NameError occcur when we assign a not decalred variable to another variable

# %%
# Handling the exceptions usign try catch block

try:
    a=b
except:
    print("The varialbe has not been assignes")
# Out:
# The varialbe has not been assignes

# %%
try:
    a=c
except NameError as e:
    print("The varialbe has not been assignes",e)
# Out:
# The varialbe has not been assignes name 'c' is not defined

# %%
result  =1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 result  =1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    res = 10/0
except ZeroDivisionError as ex:
    print("the denominator is not a valid denominator")
# Out:
# the denominator is not a valid denominator

# %%
try:
    res = 100/0
    a=d
except NameError as e:
    print("The varialbe has not been assignes")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 try:
# ----> 2     res = 100/0
#       3     a=d
#       4 except NameError as e:
#
# ZeroDivisionError: division by zero

# %%
try:
    res = 100/0
    a=d
except NameError as e:
    print("You cannot divide a number by 0")
except Exception :
    print("The varialbe has not been assigned")
# Out:
# The varialbe has not been assigned

# %%
try:
    a=10/2
except:
    print("division by zero error")
else:                                  # else part gets executed when we dont have any exception

    print("there is no error")
finally:                               # finaly block  get executed when the exception occurred or not occur
    
    print("Final block of code is running")
# Out:
# there is no error
# Final block of code is running
